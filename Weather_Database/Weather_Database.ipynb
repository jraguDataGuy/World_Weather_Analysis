# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "City Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | airai
# Processing Record 2 of Set 1 | sinazongwe
# Processing Record 3 of Set 1 | freeport
# Processing Record 4 of Set 1 | samarai
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | chaihe
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | fort oglethorpe
# Processing Record 10 of Set 1 | doha
# Processing Record 11 of Set 1 | marsa matruh
# Processing Record 12 of Set 1 | wenling
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | ibra
# Processing Record 15 of Set 1 | acarau
# Processing Record 16 of Set 1 | kautokeino
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | gorontalo
# Processing Record 21 of Set 1 | margate
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | tuatapere
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | peniche
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 1 | ixtapa
# Processing Record 32 of Set 1 | nizhniy tsasuchey
# Processing Record 33 of Set 1 | bubaque
# Processing Record 34 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 1 | comodoro rivadavia
# Processing Record 36 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | victoria
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | zonguldak
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | coos bay
# Processing Record 44 of Set 1 | rio claro
# Processing Record 45 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | srednekolymsk
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 2 | egvekinot
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | sahuaripa
# Processing Record 5 of Set 2 | namatanai
# Processing Record 6 of Set 2 | paramonga
# Processing Record 7 of Set 2 | maniitsoq
# Processing Record 8 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 9 of Set 2 | piran
# Processing Record 10 of Set 2 | corinto
# Processing Record 11 of Set 2 | ancud
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | dunedin
# Processing Record 14 of Set 2 | odweyne
# Processing Record 15 of Set 2 | bolonchen
# City not found. Skipping...
# Processing Record 16 of Set 2 | cherskiy
# Processing Record 17 of Set 2 | stekolnyy
# City not found. Skipping...
# Processing Record 18 of Set 2 | san patricio
# Processing Record 19 of Set 2 | curuca
# Processing Record 20 of Set 2 | aripuana
# Processing Record 21 of Set 2 | saint-georges
# Processing Record 22 of Set 2 | nyurba
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 2 | tasiilaq
# Processing Record 26 of Set 2 | nikolskoye
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | coihaique
# Processing Record 29 of Set 2 | santa luzia
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | morant bay
# Processing Record 33 of Set 2 | kongolo
# Processing Record 34 of Set 2 | mount gambier
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | shadrinsk
# Processing Record 37 of Set 2 | silyanah
# City not found. Skipping...
# Processing Record 38 of Set 2 | aswan
# Processing Record 39 of Set 2 | esperance
# Processing Record 40 of Set 2 | evensk
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | tautira
# Processing Record 43 of Set 2 | kholodnyy
# Processing Record 44 of Set 2 | ascension
# Processing Record 45 of Set 2 | mehamn
# Processing Record 46 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 2 | shingu
# Processing Record 48 of Set 2 | busselton
# Processing Record 49 of Set 2 | birsk
# Processing Record 50 of Set 2 | cristalina
# Processing Record 1 of Set 3 | avera
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | ales
# Processing Record 4 of Set 3 | kenai
# Processing Record 5 of Set 3 | achisay
# City not found. Skipping...
# Processing Record 6 of Set 3 | upernavik
# Processing Record 7 of Set 3 | quatre cocos
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 3 | bani
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | adrar
# Processing Record 13 of Set 3 | chuy
# Processing Record 14 of Set 3 | kavieng
# Processing Record 15 of Set 3 | vila velha
# Processing Record 16 of Set 3 | kahului
# Processing Record 17 of Set 3 | karratha
# Processing Record 18 of Set 3 | maxixe
# Processing Record 19 of Set 3 | sola
# Processing Record 20 of Set 3 | vanimo
# Processing Record 21 of Set 3 | cabo san lucas
# Processing Record 22 of Set 3 | matay
# Processing Record 23 of Set 3 | makakilo city
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | mar del plata
# Processing Record 26 of Set 3 | kesinga
# Processing Record 27 of Set 3 | brae
# Processing Record 28 of Set 3 | kidal
# Processing Record 29 of Set 3 | dikson
# Processing Record 30 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 3 | yellowknife
# Processing Record 32 of Set 3 | carnarvon
# Processing Record 33 of Set 3 | harper
# Processing Record 34 of Set 3 | poum
# Processing Record 35 of Set 3 | syracuse
# Processing Record 36 of Set 3 | opelousas
# Processing Record 37 of Set 3 | amahai
# Processing Record 38 of Set 3 | hasaki
# Processing Record 39 of Set 3 | castro
# Processing Record 40 of Set 3 | peterhead
# Processing Record 41 of Set 3 | hermanus
# Processing Record 42 of Set 3 | salinopolis
# Processing Record 43 of Set 3 | chapais
# Processing Record 44 of Set 3 | llanes
# Processing Record 45 of Set 3 | port blair
# Processing Record 46 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 3 | anisoc
# Processing Record 48 of Set 3 | pangody
# Processing Record 49 of Set 3 | barrow
# Processing Record 50 of Set 3 | albany
# Processing Record 1 of Set 4 | fortuna
# Processing Record 2 of Set 4 | narasannapeta
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | farafangana
# Processing Record 5 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 6 of Set 4 | hambantota
# Processing Record 7 of Set 4 | kamenka
# Processing Record 8 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 4 | grindavik
# Processing Record 10 of Set 4 | georgetown
# Processing Record 11 of Set 4 | saldanha
# Processing Record 12 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 4 | severo-kurilsk
# Processing Record 14 of Set 4 | rwamagana
# Processing Record 15 of Set 4 | petropavlovka
# Processing Record 16 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 4 | broken hill
# Processing Record 18 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 4 | sosnovka
# Processing Record 20 of Set 4 | vardo
# Processing Record 21 of Set 4 | hithadhoo
# Processing Record 22 of Set 4 | beira
# Processing Record 23 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | mao
# Processing Record 26 of Set 4 | touros
# Processing Record 27 of Set 4 | aykhal
# Processing Record 28 of Set 4 | saint anthony
# Processing Record 29 of Set 4 | ajdabiya
# Processing Record 30 of Set 4 | novyy urengoy
# Processing Record 31 of Set 4 | flinders
# Processing Record 32 of Set 4 | port hedland
# Processing Record 33 of Set 4 | dingle
# Processing Record 34 of Set 4 | oksfjord
# Processing Record 35 of Set 4 | kolpny
# Processing Record 36 of Set 4 | jaramana
# City not found. Skipping...
# Processing Record 37 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 4 | velestinon
# City not found. Skipping...
# Processing Record 39 of Set 4 | rovaniemi
# Processing Record 40 of Set 4 | paita
# Processing Record 41 of Set 4 | akhtubinsk
# Processing Record 42 of Set 4 | pangnirtung
# Processing Record 43 of Set 4 | innisfail
# Processing Record 44 of Set 4 | lata
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | kungurtug
# Processing Record 47 of Set 4 | mahanoro
# Processing Record 48 of Set 4 | igarka
# Processing Record 49 of Set 4 | yulara
# Processing Record 50 of Set 4 | vila do maio
# Processing Record 1 of Set 5 | blagoyevo
# Processing Record 2 of Set 5 | keflavik
# Processing Record 3 of Set 5 | rocha
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | faanui
# Processing Record 6 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 5 | neiafu
# Processing Record 8 of Set 5 | marsh harbour
# Processing Record 9 of Set 5 | saint-joseph
# Processing Record 10 of Set 5 | saint-philippe
# Processing Record 11 of Set 5 | khatanga
# Processing Record 12 of Set 5 | ilhabela
# Processing Record 13 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 5 | kilindoni
# Processing Record 15 of Set 5 | henties bay
# Processing Record 16 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 17 of Set 5 | adre
# Processing Record 18 of Set 5 | bambous virieux
# Processing Record 19 of Set 5 | hobyo
# Processing Record 20 of Set 5 | flin flon
# Processing Record 21 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 5 | lasa
# Processing Record 23 of Set 5 | tigzirt
# Processing Record 24 of Set 5 | camanci
# City not found. Skipping...
# Processing Record 25 of Set 5 | praia da vitoria
# Processing Record 26 of Set 5 | lufilufi
# Processing Record 27 of Set 5 | lagoa
# Processing Record 28 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 5 | siniscola
# Processing Record 30 of Set 5 | along
# Processing Record 31 of Set 5 | hastings
# Processing Record 32 of Set 5 | san pedro jocopilas
# Processing Record 33 of Set 5 | haines junction
# Processing Record 34 of Set 5 | yorkton
# Processing Record 35 of Set 5 | altay
# Processing Record 36 of Set 5 | bagu
# Processing Record 37 of Set 5 | codrington
# Processing Record 38 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 39 of Set 5 | sinnamary
# Processing Record 40 of Set 5 | cortez
# Processing Record 41 of Set 5 | severo-yeniseyskiy
# Processing Record 42 of Set 5 | yala
# Processing Record 43 of Set 5 | caravelas
# Processing Record 44 of Set 5 | tres arroyos
# Processing Record 45 of Set 5 | svetlyy
# Processing Record 46 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 47 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 5 | kerteh
# City not found. Skipping...
# Processing Record 49 of Set 5 | strezhevoy
# Processing Record 50 of Set 5 | aguimes
# Processing Record 1 of Set 6 | longyearbyen
# Processing Record 2 of Set 6 | nome
# Processing Record 3 of Set 6 | lorengau
# Processing Record 4 of Set 6 | amapala
# Processing Record 5 of Set 6 | aklavik
# Processing Record 6 of Set 6 | bonavista
# Processing Record 7 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 8 of Set 6 | el naranjo
# Processing Record 9 of Set 6 | fairbanks
# Processing Record 10 of Set 6 | dicabisagan
# Processing Record 11 of Set 6 | bredasdorp
# Processing Record 12 of Set 6 | sawakin
# Processing Record 13 of Set 6 | thinadhoo
# Processing Record 14 of Set 6 | turkistan
# Processing Record 15 of Set 6 | santa cruz
# Processing Record 16 of Set 6 | husavik
# Processing Record 17 of Set 6 | clyde river
# Processing Record 18 of Set 6 | xiongshi
# City not found. Skipping...
# Processing Record 19 of Set 6 | kattivakkam
# Processing Record 20 of Set 6 | havoysund
# Processing Record 21 of Set 6 | beloha
# Processing Record 22 of Set 6 | souillac
# Processing Record 23 of Set 6 | guadalajara
# Processing Record 24 of Set 6 | kieta
# Processing Record 25 of Set 6 | san carlos de bariloche
# Processing Record 26 of Set 6 | liverpool
# Processing Record 27 of Set 6 | san cristobal
# Processing Record 28 of Set 6 | olafsvik
# Processing Record 29 of Set 6 | college
# Processing Record 30 of Set 6 | aksarka
# Processing Record 31 of Set 6 | geraldton
# Processing Record 32 of Set 6 | bathsheba
# Processing Record 33 of Set 6 | hamilton
# Processing Record 34 of Set 6 | tamazulapam
# City not found. Skipping...
# Processing Record 35 of Set 6 | buenos aires
# Processing Record 36 of Set 6 | minab
# Processing Record 37 of Set 6 | sept-iles
# Processing Record 38 of Set 6 | iqaluit
# Processing Record 39 of Set 6 | curaca
# Processing Record 40 of Set 6 | billings
# Processing Record 41 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 42 of Set 6 | north bend
# Processing Record 43 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 6 | marataizes
# Processing Record 45 of Set 6 | tinskoy
# Processing Record 46 of Set 6 | ngunguru
# Processing Record 47 of Set 6 | todos santos
# Processing Record 48 of Set 6 | ybbs
# City not found. Skipping...
# Processing Record 49 of Set 6 | hofn
# Processing Record 50 of Set 6 | carutapera
# Processing Record 1 of Set 7 | wanning
# Processing Record 2 of Set 7 | tsabong
# Processing Record 3 of Set 7 | moses lake
# Processing Record 4 of Set 7 | sur
# Processing Record 5 of Set 7 | isla mujeres
# Processing Record 6 of Set 7 | salalah
# Processing Record 7 of Set 7 | kudahuvadhoo
# Processing Record 8 of Set 7 | cayenne
# Processing Record 9 of Set 7 | bengkulu
# Processing Record 10 of Set 7 | molepolole
# Processing Record 11 of Set 7 | khandyga
# Processing Record 12 of Set 7 | uige
# Processing Record 13 of Set 7 | taoudenni
# Processing Record 14 of Set 7 | port hardy
# Processing Record 15 of Set 7 | miri
# Processing Record 16 of Set 7 | contamana
# Processing Record 17 of Set 7 | ugoofaaru
# Processing Record 18 of Set 7 | galeana
# Processing Record 19 of Set 7 | guerrero negro
# Processing Record 20 of Set 7 | gamba
# Processing Record 21 of Set 7 | glendive
# Processing Record 22 of Set 7 | klaksvik
# Processing Record 23 of Set 7 | saveh
# Processing Record 24 of Set 7 | thompson
# Processing Record 25 of Set 7 | tilichiki
# Processing Record 26 of Set 7 | padampur
# Processing Record 27 of Set 7 | hilton head island
# Processing Record 28 of Set 7 | siteki
# Processing Record 29 of Set 7 | alofi
# Processing Record 30 of Set 7 | wellington
# Processing Record 31 of Set 7 | graham
# Processing Record 32 of Set 7 | magadan
# Processing Record 33 of Set 7 | tukrah
# Processing Record 34 of Set 7 | lavrentiya
# Processing Record 35 of Set 7 | beyneu
# Processing Record 36 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 7 | saint-augustin
# Processing Record 38 of Set 7 | tarime
# Processing Record 39 of Set 7 | baruun-urt
# Processing Record 40 of Set 7 | san gabriel
# Processing Record 41 of Set 7 | wanxian
# Processing Record 42 of Set 7 | churachandpur
# Processing Record 43 of Set 7 | santa barbara
# Processing Record 44 of Set 7 | atar
# Processing Record 45 of Set 7 | bac lieu
# Processing Record 46 of Set 7 | severomuysk
# Processing Record 47 of Set 7 | meulaboh
# Processing Record 48 of Set 7 | turkan
# Processing Record 49 of Set 7 | kavaratti
# Processing Record 50 of Set 7 | anori
# Processing Record 1 of Set 8 | turinsk
# Processing Record 2 of Set 8 | port macquarie
# Processing Record 3 of Set 8 | bereda
# Processing Record 4 of Set 8 | laguna
# Processing Record 5 of Set 8 | sivaki
# Processing Record 6 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 8 | san quintin
# Processing Record 8 of Set 8 | mount vernon
# Processing Record 9 of Set 8 | kaitangata
# Processing Record 10 of Set 8 | auki
# Processing Record 11 of Set 8 | kristiansund
# Processing Record 12 of Set 8 | ust-tsilma
# Processing Record 13 of Set 8 | yerbogachen
# Processing Record 14 of Set 8 | hyeres
# Processing Record 15 of Set 8 | prince rupert
# Processing Record 16 of Set 8 | sovetskiy
# Processing Record 17 of Set 8 | ola
# Processing Record 18 of Set 8 | dahanu
# Processing Record 19 of Set 8 | escanaba
# Processing Record 20 of Set 8 | miura
# Processing Record 21 of Set 8 | savelugu
# Processing Record 22 of Set 8 | baykit
# Processing Record 23 of Set 8 | invermere
# Processing Record 24 of Set 8 | beberibe
# Processing Record 25 of Set 8 | mae chan
# Processing Record 26 of Set 8 | axim
# Processing Record 27 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 8 | tsnori
# Processing Record 29 of Set 8 | tiksi
# Processing Record 30 of Set 8 | port lincoln
# Processing Record 31 of Set 8 | canillo
# Processing Record 32 of Set 8 | sisimiut
# Processing Record 33 of Set 8 | melfort
# Processing Record 34 of Set 8 | bilma
# Processing Record 35 of Set 8 | pisco
# Processing Record 36 of Set 8 | preobrazheniye
# Processing Record 37 of Set 8 | bilibino
# Processing Record 38 of Set 8 | bandarbeyla
# Processing Record 39 of Set 8 | valky
# Processing Record 40 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 41 of Set 8 | vestmannaeyjar
# Processing Record 42 of Set 8 | saint george
# Processing Record 43 of Set 8 | kandrian
# Processing Record 44 of Set 8 | afsin
# Processing Record 45 of Set 8 | butterworth
# Processing Record 46 of Set 8 | isangel
# Processing Record 47 of Set 8 | norman wells
# Processing Record 48 of Set 8 | alice springs
# Processing Record 49 of Set 8 | necochea
# Processing Record 50 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 1 of Set 9 | sungaipenuh
# Processing Record 2 of Set 9 | tezu
# Processing Record 3 of Set 9 | leningradskiy
# Processing Record 4 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 9 | port augusta
# Processing Record 6 of Set 9 | ballina
# Processing Record 7 of Set 9 | maridi
# Processing Record 8 of Set 9 | ayotzintepec
# Processing Record 9 of Set 9 | linchuan
# City not found. Skipping...
# Processing Record 10 of Set 9 | walvis bay
# Processing Record 11 of Set 9 | somerton
# Processing Record 12 of Set 9 | ahipara
# Processing Record 13 of Set 9 | qeshm
# Processing Record 14 of Set 9 | quesada
# Processing Record 15 of Set 9 | diamantina
# Processing Record 16 of Set 9 | algarrobo
# Processing Record 17 of Set 9 | kruisfontein
# Processing Record 18 of Set 9 | seaford
# Processing Record 19 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 9 | nara
# Processing Record 21 of Set 9 | mumbwa
# Processing Record 22 of Set 9 | lompoc
# Processing Record 23 of Set 9 | khor
# Processing Record 24 of Set 9 | the pas
# Processing Record 25 of Set 9 | dawson
# Processing Record 26 of Set 9 | deputatskiy
# Processing Record 27 of Set 9 | florence
# Processing Record 28 of Set 9 | eyl
# Processing Record 29 of Set 9 | varnavino
# Processing Record 30 of Set 9 | narsaq
# Processing Record 31 of Set 9 | cururupu
# Processing Record 32 of Set 9 | fremont
# Processing Record 33 of Set 9 | luderitz
# Processing Record 34 of Set 9 | nuuk
# Processing Record 35 of Set 9 | oistins
# Processing Record 36 of Set 9 | provideniya
# Processing Record 37 of Set 9 | meadow lake
# Processing Record 38 of Set 9 | pangai
# Processing Record 39 of Set 9 | constitucion
# Processing Record 40 of Set 9 | la sarre
# Processing Record 41 of Set 9 | tartki
# City not found. Skipping...
# Processing Record 42 of Set 9 | westport
# Processing Record 43 of Set 9 | taft
# Processing Record 44 of Set 9 | coquimbo
# Processing Record 45 of Set 9 | namibe
# Processing Record 46 of Set 9 | carnduff
# Processing Record 47 of Set 9 | banda aceh
# Processing Record 48 of Set 9 | shimoda
# Processing Record 49 of Set 9 | irece
# Processing Record 50 of Set 9 | boa vista
# Processing Record 1 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 2 of Set 10 | yar-sale
# Processing Record 3 of Set 10 | rafai
# Processing Record 4 of Set 10 | terrasini
# Processing Record 5 of Set 10 | berlevag
# Processing Record 6 of Set 10 | sakaiminato
# Processing Record 7 of Set 10 | manzhouli
# Processing Record 8 of Set 10 | naze
# Processing Record 9 of Set 10 | grafton
# Processing Record 10 of Set 10 | cartagena del chaira
# Processing Record 11 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 13 of Set 10 | albemarle
# Processing Record 14 of Set 10 | oranjestad
# Processing Record 15 of Set 10 | sao gabriel da cachoeira
# Processing Record 16 of Set 10 | gazalkent
# Processing Record 17 of Set 10 | leiyang
# Processing Record 18 of Set 10 | fomboni
# Processing Record 19 of Set 10 | port-gentil
# Processing Record 20 of Set 10 | rawson
# Processing Record 21 of Set 10 | baiao
# Processing Record 22 of Set 10 | fukue
# Processing Record 23 of Set 10 | kirakira
# Processing Record 24 of Set 10 | martapura
# Processing Record 25 of Set 10 | boffa
# Processing Record 26 of Set 10 | guzelyurt
# Processing Record 27 of Set 10 | mocuba
# Processing Record 28 of Set 10 | christchurch
# Processing Record 29 of Set 10 | batagay-alyta
# Processing Record 30 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 10 | warrington
# Processing Record 32 of Set 10 | wajid
# Processing Record 33 of Set 10 | roura
# Processing Record 34 of Set 10 | tessalit
# Processing Record 35 of Set 10 | north bay
# Processing Record 36 of Set 10 | denpasar
# Processing Record 37 of Set 10 | bethel
# Processing Record 38 of Set 10 | mishan
# Processing Record 39 of Set 10 | kupang
# Processing Record 40 of Set 10 | taksimo
# Processing Record 41 of Set 10 | bone
# Processing Record 42 of Set 10 | visby
# Processing Record 43 of Set 10 | faya
# Processing Record 44 of Set 10 | rafsanjan
# Processing Record 45 of Set 10 | san policarpo
# Processing Record 46 of Set 10 | menongue
# Processing Record 47 of Set 10 | halvad
# Processing Record 48 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 10 | teguldet
# Processing Record 50 of Set 10 | alyangula
# Processing Record 1 of Set 11 | jiuquan
# Processing Record 2 of Set 11 | itarema
# Processing Record 3 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 4 of Set 11 | terney
# Processing Record 5 of Set 11 | inhambane
# Processing Record 6 of Set 11 | aksu
# Processing Record 7 of Set 11 | ambilobe
# Processing Record 8 of Set 11 | sao felix do xingu
# Processing Record 9 of Set 11 | road town
# Processing Record 10 of Set 11 | surt
# Processing Record 11 of Set 11 | bakel
# Processing Record 12 of Set 11 | phan thiet
# Processing Record 13 of Set 11 | huarmey
# Processing Record 14 of Set 11 | zorgo
# Processing Record 15 of Set 11 | jalu
# Processing Record 16 of Set 11 | broome
# Processing Record 17 of Set 11 | sao joao da barra
# Processing Record 18 of Set 11 | yarada
# Processing Record 19 of Set 11 | dir
# Processing Record 20 of Set 11 | tarakan
# Processing Record 21 of Set 11 | cambridge
# Processing Record 22 of Set 11 | tocopilla
# Processing Record 23 of Set 11 | komsomolskiy
# Processing Record 24 of Set 11 | lahij
# Processing Record 25 of Set 11 | bunia
# Processing Record 26 of Set 11 | santa maria
# Processing Record 27 of Set 11 | veraval
# Processing Record 28 of Set 11 | viedma
# Processing Record 29 of Set 11 | marquette
# Processing Record 30 of Set 11 | yahotyn
# Processing Record 31 of Set 11 | alta floresta
# Processing Record 32 of Set 11 | lamesa
# Processing Record 33 of Set 11 | manacapuru
# Processing Record 34 of Set 11 | mandiana
# Processing Record 35 of Set 11 | guiglo
# Processing Record 36 of Set 11 | boyolangu
# Processing Record 37 of Set 11 | beruwala
# Processing Record 38 of Set 11 | zhezkazgan
# Processing Record 39 of Set 11 | champerico
# Processing Record 40 of Set 11 | nouadhibou
# Processing Record 41 of Set 11 | buchanan
# Processing Record 42 of Set 11 | sarangani
# Processing Record 43 of Set 11 | half moon bay
# Processing Record 44 of Set 11 | fossombrone
# Processing Record 45 of Set 11 | atenas
# Processing Record 46 of Set 11 | coxim
# Processing Record 47 of Set 11 | gondar
# Processing Record 48 of Set 11 | xiaoshi
# Processing Record 49 of Set 11 | matadi
# Processing Record 50 of Set 11 | ajaccio
# Processing Record 1 of Set 12 | vila
# Processing Record 2 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 3 of Set 12 | autazes
# Processing Record 4 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 5 of Set 12 | svetlogorsk
# Processing Record 6 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 12 | mount isa
# Processing Record 8 of Set 12 | balykshi
# Processing Record 9 of Set 12 | betioky
# Processing Record 10 of Set 12 | gondanglegi
# Processing Record 11 of Set 12 | krasnyy chikoy
# Processing Record 12 of Set 12 | sao filipe
# Processing Record 13 of Set 12 | kurumkan
# Processing Record 14 of Set 12 | isoka
# Processing Record 15 of Set 12 | leshukonskoye
# Processing Record 16 of Set 12 | duminichi
# Processing Record 17 of Set 12 | naron
# Processing Record 18 of Set 12 | merritt
# Processing Record 19 of Set 12 | salta
# Processing Record 20 of Set 12 | mindelo
# Processing Record 21 of Set 12 | safford
# Processing Record 22 of Set 12 | hit
# Processing Record 23 of Set 12 | acuna
# City not found. Skipping...
# Processing Record 24 of Set 12 | saint andrews
# Processing Record 25 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 26 of Set 12 | semnan
# Processing Record 27 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 28 of Set 12 | waingapu
# Processing Record 29 of Set 12 | dharchula
# Processing Record 30 of Set 12 | yenagoa
# Processing Record 31 of Set 12 | skelleftea
# Processing Record 32 of Set 12 | labuhan
# Processing Record 33 of Set 12 | nakhon phanom
# Processing Record 34 of Set 12 | leon valley
# Processing Record 35 of Set 12 | erzin
# Processing Record 36 of Set 12 | waw
# Processing Record 37 of Set 12 | torbay
# Processing Record 38 of Set 12 | qasigiannguit
# Processing Record 39 of Set 12 | concordia
# Processing Record 40 of Set 12 | tonj
# Processing Record 41 of Set 12 | muisne
# Processing Record 42 of Set 12 | kholmogory
# Processing Record 43 of Set 12 | natalio
# Processing Record 44 of Set 12 | yanam
# Processing Record 45 of Set 12 | payakumbuh
# Processing Record 46 of Set 12 | waipawa
# Processing Record 47 of Set 12 | rio grande
# Processing Record 48 of Set 12 | aksay
# Processing Record 49 of Set 12 | tual
# Processing Record 50 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 13 | hebertville
# City not found. Skipping...
# Processing Record 3 of Set 13 | takhli
# Processing Record 4 of Set 13 | bagdarin
# Processing Record 5 of Set 13 | sibi
# Processing Record 6 of Set 13 | casablanca
# Processing Record 7 of Set 13 | tigil
# Processing Record 8 of Set 13 | san martin
# Processing Record 9 of Set 13 | itamarandiba
# Processing Record 10 of Set 13 | san carlos
# Processing Record 11 of Set 13 | finschhafen
# Processing Record 12 of Set 13 | jijiga
# Processing Record 13 of Set 13 | jishou
# Processing Record 14 of Set 13 | el doncello
# Processing Record 15 of Set 13 | olbia
# Processing Record 16 of Set 13 | puerto narino
# Processing Record 17 of Set 13 | khuzhir
# Processing Record 18 of Set 13 | bayonet point
# Processing Record 19 of Set 13 | gumdag
# Processing Record 20 of Set 13 | whitehorse
# Processing Record 21 of Set 13 | severnoye
# Processing Record 22 of Set 13 | mpulungu
# Processing Record 23 of Set 13 | hervey bay
# Processing Record 24 of Set 13 | ailigandi
# Processing Record 25 of Set 13 | piney green
# Processing Record 26 of Set 13 | yambio
# Processing Record 27 of Set 13 | pochutla
# Processing Record 28 of Set 13 | noshiro
# Processing Record 29 of Set 13 | chicama
# Processing Record 30 of Set 13 | rio gallegos
# Processing Record 31 of Set 13 | santa isabel do rio negro
# Processing Record 32 of Set 13 | youhao
# Processing Record 33 of Set 13 | bardiyah
# Processing Record 34 of Set 13 | verkhnyaya inta
# Processing Record 35 of Set 13 | saint-pierre
# Processing Record 36 of Set 13 | xghajra
# City not found. Skipping...
# Processing Record 37 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 13 | palomares
# Processing Record 39 of Set 13 | almaznyy
# Processing Record 40 of Set 13 | kampot
# Processing Record 41 of Set 13 | puri
# Processing Record 42 of Set 13 | tecoanapa
# Processing Record 43 of Set 13 | alpena
# Processing Record 44 of Set 13 | hay river
# Processing Record 45 of Set 13 | sherlovaya gora
# Processing Record 46 of Set 13 | zhoucheng
# Processing Record 47 of Set 13 | sitka
# Processing Record 48 of Set 13 | ha giang
# Processing Record 49 of Set 13 | bhatkal
# Processing Record 50 of Set 13 | derzhavinsk
# Processing Record 1 of Set 14 | oeiras
# Processing Record 2 of Set 14 | moose factory
# Processing Record 3 of Set 14 | nanortalik
# Processing Record 4 of Set 14 | almirante
# Processing Record 5 of Set 14 | kralendijk
# Processing Record 6 of Set 14 | bonthe
# Processing Record 7 of Set 14 | dharan
# Processing Record 8 of Set 14 | talnakh
# Processing Record 9 of Set 14 | mwinilunga
# Processing Record 10 of Set 14 | mangan
# Processing Record 11 of Set 14 | athabasca
# Processing Record 12 of Set 14 | lima
# Processing Record 13 of Set 14 | bosaso
# Processing Record 14 of Set 14 | jodhpur
# Processing Record 15 of Set 14 | kulhudhuffushi
# Processing Record 16 of Set 14 | atikokan
# Processing Record 17 of Set 14 | xining
# Processing Record 18 of Set 14 | bulgan
# Processing Record 19 of Set 14 | ekhabi
# Processing Record 20 of Set 14 | espana
# Processing Record 21 of Set 14 | cockburn town
# Processing Record 22 of Set 14 | ostrovnoy
# Processing Record 23 of Set 14 | canar
# Processing Record 24 of Set 14 | nouakchott
# Processing Record 25 of Set 14 | belluno
# Processing Record 26 of Set 14 | bagua grande
# Processing Record 27 of Set 14 | iskateley
# Processing Record 28 of Set 14 | zwedru
# Processing Record 29 of Set 14 | manzanillo
# Processing Record 30 of Set 14 | san andres
# Processing Record 31 of Set 14 | hegang
# Processing Record 32 of Set 14 | price
# Processing Record 33 of Set 14 | porto santo
# Processing Record 34 of Set 14 | nhulunbuy
# Processing Record 35 of Set 14 | udachnyy
# Processing Record 36 of Set 14 | bara
# Processing Record 37 of Set 14 | owando
# Processing Record 38 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 39 of Set 14 | grand gaube
# Processing Record 40 of Set 14 | mogadishu
# Processing Record 41 of Set 14 | periyanayakkanpalaiyam
# Processing Record 42 of Set 14 | sedhiou
# Processing Record 43 of Set 14 | northam
# Processing Record 44 of Set 14 | newport
# Processing Record 45 of Set 14 | baripada
# Processing Record 46 of Set 14 | batemans bay
# Processing Record 47 of Set 14 | virginia beach
# Processing Record 48 of Set 14 | port shepstone
# Processing Record 49 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 50 of Set 14 | elat
# Processing Record 1 of Set 15 | svarstad
# Processing Record 2 of Set 15 | biryusinsk
# Processing Record 3 of Set 15 | kasongo
# Processing Record 4 of Set 15 | byron bay
# Processing Record 5 of Set 15 | inongo
# Processing Record 6 of Set 15 | mbuji-mayi
# Processing Record 7 of Set 15 | dalianwan
# Processing Record 8 of Set 15 | karpogory
# Processing Record 9 of Set 15 | berbera
# Processing Record 10 of Set 15 | olavarria
# Processing Record 11 of Set 15 | sao mateus
# Processing Record 12 of Set 15 | lagoa formosa
# Processing Record 13 of Set 15 | olawa
# Processing Record 14 of Set 15 | zhigansk
# Processing Record 15 of Set 15 | devonport
# Processing Record 16 of Set 15 | padang
# Processing Record 17 of Set 15 | pousat
# City not found. Skipping...
# Processing Record 18 of Set 15 | seoul
# Processing Record 19 of Set 15 | granite city
# Processing Record 20 of Set 15 | kuzhithurai
# Processing Record 21 of Set 15 | solnechnyy
# Processing Record 22 of Set 15 | jalingo
# Processing Record 23 of Set 15 | mmathubudukwane
# Processing Record 24 of Set 15 | savona
# Processing Record 25 of Set 15 | koflach
# Processing Record 26 of Set 15 | kelcyre
# Processing Record 27 of Set 15 | madang
# Processing Record 28 of Set 15 | boissevain
# Processing Record 29 of Set 15 | plouzane
# Processing Record 30 of Set 15 | morgan city
# Processing Record 31 of Set 15 | aktau
# Processing Record 32 of Set 15 | kanye
# Processing Record 33 of Set 15 | ucluelet
# Processing Record 34 of Set 15 | alekseyevsk
# Processing Record 35 of Set 15 | buala
# Processing Record 36 of Set 15 | sampit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 664

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Airai  -8.9266  125.4092     62.47        86         100
# 1       Sinazongwe -17.2614   27.4618     80.92        45          20
# 2         Freeport  40.6576  -73.5832     47.17        48           1
# 3          Samarai -10.6167  150.6667     83.59        75         100
# 4           Chaihe  44.7667  129.7000      5.70        72          33
# 5           Hobart -42.8794  147.3294     63.27        62          20
# 6          Rikitea -23.1203 -134.9692     77.65        76          87
# 7  Fort Oglethorpe  34.9490  -85.2569     51.53        49           1
# 8             Doha  25.2867   51.5333     66.18        72           0
# 9     Marsa Matruh  31.3525   27.2453     57.40        62           0
#
#    Wind Speed Country  City Description                 Date
# 0        1.72      TL   overcast clouds  2021-12-12 22:29:03
# 1        3.13      ZM        few clouds  2021-12-12 22:35:38
# 2        5.01      US         clear sky  2021-12-12 22:34:11
# 3       11.10      PG   overcast clouds  2021-12-12 22:35:38
# 4       10.69      CN  scattered clouds  2021-12-12 22:35:39
# 5        4.00      AU        few clouds  2021-12-12 22:35:39
# 6        8.63      PF        light rain  2021-12-12 22:31:21
# 7        6.91      US         clear sky  2021-12-12 22:35:39
# 8        9.22      QA         clear sky  2021-12-12 22:32:40
# 9        3.44      EG         clear sky  2021-12-12 22:31:26

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","City Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0            Airai      TL  2021-12-12 22:29:03  -8.9266  125.4092     62.47
# 1       Sinazongwe      ZM  2021-12-12 22:35:38 -17.2614   27.4618     80.92
# 2         Freeport      US  2021-12-12 22:34:11  40.6576  -73.5832     47.17
# 3          Samarai      PG  2021-12-12 22:35:38 -10.6167  150.6667     83.59
# 4           Chaihe      CN  2021-12-12 22:35:39  44.7667  129.7000      5.70
# 5           Hobart      AU  2021-12-12 22:35:39 -42.8794  147.3294     63.27
# 6          Rikitea      PF  2021-12-12 22:31:21 -23.1203 -134.9692     77.65
# 7  Fort Oglethorpe      US  2021-12-12 22:35:39  34.9490  -85.2569     51.53
# 8             Doha      QA  2021-12-12 22:32:40  25.2867   51.5333     66.18
# 9     Marsa Matruh      EG  2021-12-12 22:31:26  31.3525   27.2453     57.40
#
#    Humidity  Cloudiness  Wind Speed  City Description
# 0        86         100        1.72   overcast clouds
# 1        45          20        3.13        few clouds
# 2        48           1        5.01         clear sky
# 3        75         100       11.10   overcast clouds
# 4        72          33       10.69  scattered clouds
# 5        62          20        4.00        few clouds
# 6        76          87        8.63        light rain
# 7        49           1        6.91         clear sky
# 8        72           0        9.22         clear sky
# 9        62           0        3.44         clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
